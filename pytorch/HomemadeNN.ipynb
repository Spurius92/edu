# %% [markdown]
# This is a code from https://github.com/trekhleb/homemade-machine-learning

# %%
#With this extension we can change the initial code from other module, imported from another file and it will be updated 'on the run'.
# %load_ext autoreload
# 2 is a code to enable autoreloading. 
# %autoreload 2

import sys
# sys.path.append('C:\\Users\\Spurius\\Desktop\\digit-recognizer')
# sys.path.append('C:\\Users\\Spurius\\gits')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import math

# %%
train = pd.read_csv('C://Users//Spurius//Desktop//digit-recognizer//train.csv')
test = pd.read_csv('C://Users//Spurius//Desktop//digit-recognizer//test.csv')

# %%
train.shape, test.shape
# Out:
# ((42000, 785), (28000, 784))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Columns: 785 entries, label to pixel783
# dtypes: int8(785)
# memory usage: 31.4 MB

# %%
train = train.astype('int8')

# %%
# here we plot first 25 numbers from the dataset
numbers_to_display = 25 

num_cells = math.ceil(math.sqrt(numbers_to_display))

plt.figure(figsize=(10, 10)) #figsize before plotting :(

for image in range(numbers_to_display):
    #extract data 
    im = train[image:image+1].values
    im_label = im[0][0]
    im_pixels = im[0][1:]
    # find image size
    image_size = int(math.sqrt(im_pixels.shape[0]))
    #make square frame for the image
    frame = im_pixels.reshape(image_size, image_size)
    
    #plotting starts
    plt.subplot(num_cells, num_cells, image+1)
    plt.imshow(frame, cmap='Greys')
    plt.title(im_label)
    plt.tick_params(axis='both', which='both', bottom=False, left=False, labelbottom=False, labelleft=False)

# plot all of them    
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
x = np.arange(1, 21)
y = np.log2(x)
plt.plot(x, y)

# %%
np.log2(25)
# Out:
# 4.643856189774724
