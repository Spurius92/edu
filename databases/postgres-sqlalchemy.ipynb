# %%
# !pip install sqlalchemy
# !pip install psycopg2-binary
# Out:
# ...
#     100% |████████████████████████████████| 2.9MB 3.1MB/s ta 0:00:011
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
creds = 'postgresql://user:password@host:5432/postgres'

# %%
engine = create_engine(creds)

# %%
df = pd.read_sql_query('select * from gazeta limit 10',con=engine)

# %%
df
# Out:
#                  date                                                url  \
# 0 2012-09-27 10:54:51  https://www.gazeta.ru/science/news/2012/09/27/...
# 1 2015-12-01 15:28:45      https://www.gazeta.ru/army/news/7957079.shtml
# 2 2013-04-18 16:42:06  https://www.gazeta.ru/travel/news/2013/04/18/n...
# 3 2012-09-26 13:54:13  https://www.gazeta.ru/politics/news/2012/09/26...
# 4 2012-09-26 21:11:33  https://www.gazeta.ru/culture/news/2012/09/26/...
# 5 2012-09-28 14:12:16  https://www.gazeta.ru/politics/news/2012/09/28...
# 6 2015-06-15 10:00:11  https://www.gazeta.ru/social/2015/06/14/684125...
# 7 2011-02-24 16:40:29  https://www.gazeta.ru/news/sport/2011/02/24/n_...
# 8 2012-09-27 10:32:37  https://www.gazeta.ru/culture/news/2012/09/27/...
# 9 2012-09-27 10:36:58  https://www.gazeta.ru/culture/news/2012/09/27/...
#
#   edition    topics              authors  \
# 0       -     Наука                 None
# 1       -     Армия                 None
# ...
